# %% [markdown]
# # 7.1 Random variable
# - Random variable: A numerical variable whose value depends on the outcome of a chance experiment. A random variable associates a numerical value with each outcome of a chance experiment.
# - Discrete random variable: A random variable is discrete if its set of possible values is a collection of isolated points along the number line.
# - Continuous random variable: A random variable is continuous if its set of possible values includes an entire interval on the number line.

# %% [markdown]
# # 7.2 Probability Distributions for Discrete Random Variables
# The probability distribution of a discrete random variable 𝒙 gives the probability associated with each possible 𝑥 value. Each probability is the long-run relative frequency of occurrence of the corresponding 𝑥 value when a chance experiment is performed a very large number of times.
# - For every possible 𝑥 value, #0 \le 𝑝(𝑥) \le 1.#
# - $\sum_{x} 𝑝(𝑥) =1$

# %% [markdown]
# # 7.3 Probability Distributions for Continuous Random Variables
# A probability distribution for a continuous random variable 𝒙 is specified by a curve called a **density curve**. The function that defines this curve is denoted by 𝑓(𝑥) and it is called the **probability density function (pdf)**.
# - $𝑓(𝑥) \ge 0$ (the curve cannot dip below the horizontal axis).
# - The total area under the density curve is equal to 1.
# - The probability that 𝒙 falls in any particular interval is equal to the area under the density curve and above the interval.
# - If 𝑥 is a continuous random variable, then for any two numbers 𝑎 and 𝑏 with 𝑎<𝑏,
# $$𝑃(𝑎 \le 𝑥 \le 𝑏)=𝑃(𝑎<𝑥<𝑏)=𝑃(𝑎 \le 𝑥 < 𝑏)=𝑃(𝑎< 𝑥 \le 𝑏)$$
# - The probability that a continuous random variable 𝑥 lies between a lower limit 𝑎 and an upper limit 𝑏 is
# $$𝑃(𝑎<𝑥<𝑏)=𝑃(𝑥<𝑏)−𝑃(𝑥>𝑎)$$

# %% [markdown]
# # 7.4 Mean and Standard Deviation of a Random Variable
# - The mean value of a random variable 𝒙, denoted by $\mu_𝑥$, describes where the probability distribution of 𝒙 is centered.
# - The standard deviation of a random variable 𝒙, denoted b $\sigma_𝑥$, describes variability in the probability distribution.

# %% [markdown]
# ## calculating Mean Value of a Discrete Random Variable
# - $\mu_𝑥$, is calculated by first multiplying each possible 𝑥 value by the probability of observing that value and then adding the resulting quantities:
# $$\mu_𝑥=\sum_{x} (𝑥 \cdot 𝑝(𝑥))$$
# - The term expected value is sometimes used in place of mean value, and 𝑬(𝑿) is another way to denote $\mu_𝑥$.

# %% [markdown]
# ## calculating standard deviation of a discrete random variable
# - The variance of a discrete random variable 𝑥, denoted by $\sigma_𝑥^2$, is calculated by
# 1.subtracting the mean from each possible 𝑥 value to obtain the deviations
# 2. squaring each deviation
# 3. multiplying each squared deviation by the probability of the corresponding 𝑥 value
# 4. $$\sigma_𝑥^2=\sum_{x} (𝑥− \mu_𝑥)^2 𝑝(𝑥)$$
#
# The standard deviation of a discrete random variable 𝑥, denoted by $\sigma_𝑥$, is the square root of the variance.

# %% [markdown]
# # 7.5 Binomial and Geometric Distributions

# %% [markdown]
# ## Binomial distributions
# A **binomial experiment** consists of a sequence of trials with the following conditions:
# 1. There are a fixed number of trials.
# 2. Each trial can result in one of only two possible outcomes, labeled success (S) and failure (F).
# 3. Outcomes of different trials are independent.
# 4. The probability that a trial results in a success is the same for each trial.
#
# The **binomial random variable** $x$ is defined as $x$ = number of successes observed when a binomial experiment is performed.
# The probability distribution of x is called the **binomial probability distribution**.

# %% [markdown]
# ###  The Binomial Distribution
# Notation:
# n = number of independent trials in a binomial experiment<br>
# p = probability of success for each trial
#
# Then
# \begin{align}
# P(x) &= P(\text{x successes among n trials})\\
# &=  {n \choose x} p^x(1-p)^{n-x}
# \end{align}
# where ${n \choose x} = \frac{n!}{x!(n-x)!}$ is the notation for *n choose x*.

# %% [markdown]
# ## Geometric Distributions
# Suppose an experiment consists of a sequence of trials with the following conditions:
# 1. The trials are independent.
# 2. Each trial can result in one of two possible outcomes, success and failure.
# 3. The probability of success is the same for all trials.
#
# A **geometric random variable** is defined as
# $x$ = number of trials until the first success is observed   (including the success trial).
# The probability distribution of x is called the **geometric probability distribution**.

# %% [markdown]
# ### Geometric Probability Distribution
# If x is a geometric random variable with probability of success = p for each trial, then
# $$p(x) = (1-p)^{x-1} p $$

# %% [markdown]
# # 7.6 Normal distributions
# Normal distributions are continuous probability distributions that are bell-shaped and symmetric, as the red curve shown in following figure.

# %%
# Plotting samples from normal distributions of mean 0 and standard deviation 1
# and the pdf of normal distributions of such

import numpy as np
import matplotlib.pyplot as plt

mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
plt.show()

# %% [markdown]
# ## Standard normal distribution
# The normal distribution with $\mu=0$ and $\sigma =1$ is called the **standard normal distribution**.
# The corresponding density curve is called the **standard normal curve**.
# The letter 𝑧 is used to represent a variable whose distribution is described by the standard normal curve. The term 𝒛 curve is often used in place of standard normal curve.

# %% [markdown]
# ## working with standard normal distribution
# We must be able to use the normal distribution to calculate probabilities, which are areas under a normal curve and above given intervals.
# We must be able to characterize extreme values in the distribution, such as the largest 5%, the smallest 1%, and the most extreme 5% (which would include both the largest 2.5% and the smallest 2.5%).

# %% [markdown]
# ## Reading #P(z < z*) from z-score table
# For any number $𝑧^*$ between −3.89 and 3.89 and rounded to two decimal places, z-score table (e.g. https://www.z-table.com/) gives area under 𝑧 𝑐𝑢𝑟𝑣𝑒 to the left of $𝑧^∗$:
# $𝑃(𝑧<𝑧^∗)=𝑃(𝑧 \le 𝑧^*), where the letter 𝑧 is used to represent a random variable whose distribution is the standard normal distribution.
# To find this probability using the table, locate the following:
# 1. The row labeled with the sign of $𝑧^∗$ and the digit to either side of the decimal point (for example, −1.75 or 0.5)
# 2. The column identified with the second digit to the right of the decimal point in $𝑧^∗$ (for example, 0.06 if 𝑧=−1.76)
#
# The number at the intersection of this row and column is the probability.

# %% [markdown]
# ## P(z > c) and P(a <> z <> b)
# - $P(𝑧>𝑐)$=area under the 𝑧 curve to the right of 𝑐 = 1− $𝑃(𝑧 < 𝑐)$
# - $𝑃(𝑎<𝑧<𝑏)$=area under the 𝑧 curve and above the interval from 𝑎 to 𝑏 =$𝑃(𝑧<𝑏)−𝑃(𝑧<𝑎)$

# %% [markdown]
# ## Identifying Extreme Values
# - smallest 2% case: Find $z^*$ such that $𝑃(𝑧<𝑧^∗)=0.02$. This gives $𝑧^∗=−2.05$.
# - largest 5%: Find $z^*$ such that $𝑃(𝑧>𝑧^∗)=0.05$. This gives $𝑧^∗=1.645$.
# - most extreme 5%: Find $z^*$ such that $𝑃(𝑧>𝑧^∗)= 0.05/2 = 0.025$. This gives $𝑧^∗=1.96$.
#     - Because the standard normal distribution is symmetric, the most extreme 5% is equally divided between the high side and the low side of the distribution, resulting in an area of 2.5% for each of the tails of the 𝑧 curve. Symmetry about 0 implies that if $𝑧^∗$ denotes the value that separates the largest 2.5%, the value that separates the smallest 2.5% is $-z^*$.

# %% [markdown]
# ## Finding Normal Distribution Probabilities

# %% [markdown]
# To calculate probabilities for **any** normal distribution, standardize the appropriate interval endpoints and then use technology or the table of 𝑧 curve areas.
# More specifically, if 𝑥 is a variable whose behavior is described by a normal distribution with mean 𝜇 and standard deviation 𝜎, then $𝑃(𝑥<𝑏)=𝑃(𝑧<𝑏^∗)$, $𝑃(𝑥>𝑎)=𝑃(𝑧>𝑎^∗)$ and $𝑃(𝑎<𝑥<𝑏)=𝑃(𝑎^∗<𝑧<𝑏^∗)$, where 𝑧 is a variable whose distribution is standard normal and
#  $$𝑎^∗=(𝑎−\mu)/\sigma, 𝑏^∗=(𝑏−\mu)/\sigma$$

# %% [markdown]
# # 7.7 checking normality

# %% [markdown]
# ## Normal probability plot: (Ex7.31)
# A scatterplot of the (normal score, observed value) pairs.
#
# A strong linear pattern in a normal probability plot suggests it is reasonable to think that the population distribution is normal. On the other hand, systematic departure from a straight-line pattern (such as curvature in the plot) indicates that it is not reasonable to assume that the population distribution is normal.

# %%
import statsmodels.graphics.gofplots as sm
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
url = "https://github.com/cocoxhuang/STAT213/blob/main/Ex07.32.csv?raw=true"
data = pd.read_csv(url)
data
# Out:
#     Year  Precipitation  sqrt(Precipitation)
# 0      1           0.77                 0.88
# 1      2           1.74                 1.32
# 2      3           0.81                 0.90
# 3      4           1.20                 1.10
# 4      5           1.95                 1.40
# 5      6           1.20                 1.10
# 6      7           0.47                 0.69
# 7      8           1.43                 1.20
# 8      9           3.37                 1.84
# 9     10           2.20                 1.48
# 10    11           3.00                 1.73
# 11    12           3.09                 1.76
# 12    13           1.51                 1.23
# 13    14           2.10                 1.45
# 14    15           0.52                 0.72
# 15    16           1.62                 1.27
# 16    17           1.31                 1.14
# 17    18           0.32                 0.57
# 18    19           0.59                 0.77
# 19    20           0.81                 0.90
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 7))
# Histogram with normal curve for comparison
sns.histplot(data['Precipitation'],kde=True, color ='blue',ax=ax[0]) 
# Normal probability plot
sm.ProbPlot(data['Precipitation']).qqplot(line='s', ax=ax[1])
